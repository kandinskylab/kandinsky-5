# %%
import os
os.chdir("..")

from kandinsky import get_T2V_pipeline
from IPython.display import Video

# %% [markdown]
# Lite SFT

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_lite_t2v_5s_sft_sd.yaml"
)
out = pipe("A dog in a green hat.", time_length=5, width=768, height=512, save_path='./test00.mp4')
Video('./test00.mp4')

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_lite_t2v_10s_sft_sd.yaml"
)
out = pipe("A dog in a blue hat.", time_length=10, width=768, height=512, save_path='./test01.mp4')
Video('./test01.mp4')

# %% [markdown]
# Lite NoCFG

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_lite_t2v_5s_nocfg_sd.yaml"
)
out = pipe("A fox in a green hat.", time_length=5, width=768, height=512, save_path='./test02.mp4')
Video('./test02.mp4')

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_lite_t2v_10s_nocfg_sd.yaml"
)
out = pipe("A fox in a blue hat.", time_length=10, width=768, height=512, save_path='./test03.mp4')
Video('./test03.mp4')

# %% [markdown]
# Lite Distil

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_lite_t2v_5s_distil_sd.yaml"
)
out = pipe("Cheburashka in a green hat", time_length=5, width=768, height=512, save_path='./test04.mp4')
Video('./test04.mp4')

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_lite_t2v_10s_distil_sd.yaml"
)
out = pipe("Cheburashka in a blue hat", time_length=10, width=768, height=512, save_path='./test05.mp4')
Video('./test05.mp4')

# %% [markdown]
# Pro  SFT

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_pro_t2v_5s_sft_sd.yaml"
)
out = pipe("A bear in a green hat.", time_length=5, width=768, height=512, save_path='./test06.mp4')
Video('./test06.mp4')

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_pro_t2v_10s_sft_sd.yaml", offload=True
)
out = pipe("A bear in a blue hat.", time_length=10, width=768, height=512, save_path='./test07.mp4')
Video('./test07.mp4')

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_pro_t2v_5s_sft_hd.yaml", offload=True
)
out = pipe("A bear in a yellow hat.", time_length=5, width=1280, height=768, save_path='./test08.mp4')
Video('./test08.mp4')

# %%
pipe = get_T2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
    conf_path="./configs/k5_pro_t2v_10s_sft_hd.yaml", offload=True
)
out = pipe("A bear in a red hat.", time_length=10, width=1280, height=768, save_path='./test09.mp4')
Video('./test09.mp4')
