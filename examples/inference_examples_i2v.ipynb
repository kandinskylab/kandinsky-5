# %%
import os
os.chdir("..")

from IPython.display import Video
from kandinsky import get_I2V_pipeline

# %%
pipe = get_I2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
	conf_path="./configs/k5_lite_i2v_5s_sft_sd.yaml"
)
res = pipe(
    "The bear plays balalaika.",
	image = "assets/test_image.jpg",
    time_length=5,
	seed=137,
	num_steps=50,
    save_path='./test0.mp4',
)
Video("./test0.mp4")

# %%
pipe = get_I2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
	conf_path="./configs/k5_pro_i2v_5s_sft_sd.yaml"
)
res = pipe(
    "The bear plays balalaika.",
	image = "assets/test_image.jpg",
    time_length=5,
	seed=137,
	num_steps=50,
    save_path='./test1.mp4',
)
Video("./test1.mp4")

# %%
pipe = get_I2V_pipeline(
    device_map={"dit": "cuda:0", "vae": "cuda:0", "text_embedder": "cuda:0"},
	conf_path="./configs/k5_pro_i2v_5s_sft_hd.yaml", offload=True
)
res = pipe(
    "The bear plays balalaika.",
	image = "assets/test_image.jpg",
    time_length=5,
	seed=137,
	num_steps=50,
    save_path='./test2.mp4',
)
Video("./test2.mp4")
